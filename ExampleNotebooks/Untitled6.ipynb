# %%
import  numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
SOL=np.load('forceSol.npy')
MG=np.load('forceMG.npy')
LG=np.load('forceLG.npy')
torque=np.load('torque.npy')
t = np.arange(0, SOL.shape[0])*0.05
t.shape[0]
# Out:
# 100000

# %%
plt.figure()
plt.plot(t, torque[:,8,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
SOL.shape
# Out:
# (100000, 9, 5)

# %%
SOL.shape
# Out:
# (9, 6000)

# %%
condVelS = np.linspace(44/2.0, 44*2.0, 5)
condVelFR = np.linspace(51/2.0, 51*2.0, 7)
condVelFF1 = np.linspace(52/2.0, 52*2.0, 5)
condVelFF2 = np.linspace(53/2.0,53*2, 5)

# %%
condVelS
# Out:
# array([ 22. ,  38.5,  55. ,  71.5,  88. ])

# %%
condVelFR
# Out:
# array([  25.5 ,   38.25,   51.  ,   63.75,   76.5 ,   89.25,  102.  ])
