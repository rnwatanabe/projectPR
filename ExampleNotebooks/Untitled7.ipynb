# %%
import numpy as np

# %%
X=np.load('spikes.npy')

# %%
X['FR0delay4']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-5f26122f9d0f> in <module>()
# ----> 1 X['FR0delay4']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-1d61f6e5db90> in <module>()
# ----> 1 X[0]
#
# IndexError: too many indices for array

# %%
pkl_file = open('myfile.pkl', 'rb')
mydict2 = pickle.load(pkl_file)
pkl_file.close()

# %%
import pickle

# %%
mydict2['FR0delay4']
# Out:
# array([[ 32.35,   0.  ],
#        [ 70.1 ,   0.  ],
#        [ 32.4 ,   1.  ],
#        [ 69.05,   1.  ],
#        [ 99.45,   1.  ],
#        [ 99.6 ,   2.  ]])

# %%
f = open('spikeTimes.pkl','rb')
spikesSOLSoma, spikesMGSoma, spikesLGSoma = pickle.load(f)

# %%
spikesSOLSoma
# Out:
# {'FR0delay0': array([[  5.05,   0.  ],
#         [ 28.5 ,   0.  ],
#         [ 51.4 ,   0.  ],
#         [ 73.15,   0.  ],
#         [ 94.15,   0.  ],
#         [ 10.7 ,   1.  ],
#         [ 34.65,   1.  ],
#         [ 63.3 ,   1.  ],
#         [ 90.6 ,   1.  ],
#         [ 10.45,   2.  ],
#         [ 34.85,   2.  ],
#         [ 59.45,   2.  ],
#         [ 84.1 ,   2.  ],
#         [ 10.45,   3.  ],
#         [ 36.4 ,   3.  ],
#         [ 63.1 ,   3.  ],
#         [ 88.15,   3.  ],
#         [  9.7 ,   4.  ],
#         [ 34.65,   4.  ],
#         [ 56.7 ,   4.  ],
#         [ 79.5 ,   4.  ],
#         [ 11.8 ,   5.  ],
#         [ 40.05,   5.  ],
#         [ 64.75,   5.  ],
#         [ 93.8 ,   5.  ],
#         [ 14.  ,   6.  ],
#         [ 44.1 ,   6.  ],
#         [ 74.15,   6.  ],
#         [  8.45,   7.  ],
#         [ 30.8 ,   7.  ],
#         [ 52.45,   7.  ],
#         [ 73.75,   7.  ],
#         [ 94.75,   7.  ],
#         [  8.9 ,   8.  ],
#         [ 31.65,   8.  ],
# ...
